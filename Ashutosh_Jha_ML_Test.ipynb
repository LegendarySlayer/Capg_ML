# %%
import pandas as pd 
import numpy as py 
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score , mean_squared_error , mean_absolute_error

# %%
df = pd.read_csv("Melbourne.csv")
df
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St      2    h        NaN     SS
# 1        Abbotsford        85 Turner St      2    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4        Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u        NaN     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h        NaN      S
# 23544     Yallambie        17 Amaroo Wy      4    h  1100000.0      S
# 23545    Yarraville          6 Agnes St      4    h  1285000.0     SP
# 23546    Yarraville       33 Freeman St      4    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23547 entries, 0 to 23546
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         23547 non-null  object
#  1   Address        23547 non-null  object
#  2   Rooms          23547 non-null  int64
#  3   Type           23547 non-null  object
#  4   Price          18396 non-null  float64
#  5   Method         23547 non-null  object
#  6   SellerG        23547 non-null  object
#  7   Date           23547 non-null  object
#  8   Distance       23546 non-null  float64
#  9   Postcode       23546 non-null  float64
#  10  Bedroom2       19066 non-null  float64
#  11  Bathroom       19063 non-null  float64
#  12  Car            18921 non-null  float64
#  13  Landsize       17410 non-null  float64
#  14  BuildingArea   10018 non-null  float64
#  15  YearBuilt      11540 non-null  float64
#  16  CouncilArea    15656 non-null  object
# ...

# %%
#price colm correction

pd.options.display.float_format = '{:.0f}'.format
pm = df['Price'].mean()
df['Price'].fillna(pm , inplace = True)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\3578272623.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price'].fillna(pm , inplace = True)

# %%
df
# Out:
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# 4        Abbotsford        5 Charles St      3    h 1465000     SP
# ...             ...                 ...    ...  ...     ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u 1056697     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h 1056697      S
# 23544     Yallambie        17 Amaroo Wy      4    h 1100000      S
# 23545    Yarraville          6 Agnes St      4    h 1285000     SP
# 23546    Yarraville       33 Freeman St      4    h 1050000     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03-09-2016         2      3067  ...         1    1
# ...

# %%
# pd.options.display.float_format = '{:.0f}'.format
# Correcting dist colmn
dm = df['Distance'].mean()
df['Distance'].fillna(dm , inplace = True)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\710734304.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Distance'].fillna(dm , inplace = True)

# %%
df
# Out:
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# 4        Abbotsford        5 Charles St      3    h 1465000     SP
# ...             ...                 ...    ...  ...     ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u 1056697     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h 1056697      S
# 23544     Yallambie        17 Amaroo Wy      4    h 1100000      S
# 23545    Yarraville          6 Agnes St      4    h 1285000     SP
# 23546    Yarraville       33 Freeman St      4    h 1050000     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03-09-2016         2      3067  ...         1    1
# ...

# %%
pcm = df['Postcode'].mean()
df['Postcode'].fillna(pcm , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\165567106.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Postcode'].fillna(pcm , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
# property count
ppcm = df['Propertycount'].mean()
df['Propertycount'].fillna(ppcm , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\3333086070.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Propertycount'].fillna(ppcm , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
rn = df['Regionname'].mode()[0]
df['Regionname'].fillna(rn , inplace = True)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\569685190.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Regionname'].fillna(rn , inplace = True)

# %%
df
# Out:
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# 4        Abbotsford        5 Charles St      3    h 1465000     SP
# ...             ...                 ...    ...  ...     ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u 1056697     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h 1056697      S
# 23544     Yallambie        17 Amaroo Wy      4    h 1100000      S
# 23545    Yarraville          6 Agnes St      4    h 1285000     SP
# 23546    Yarraville       33 Freeman St      4    h 1050000     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03-09-2016         2      3067  ...         1    1
# ...

# %%
# Bedroom2
bd = df['Bedroom2'].mean()
df['Bedroom2'].fillna(bd , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\44299766.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Bedroom2'].fillna(bd , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             0
# Postcode             0
# Bedroom2             0
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           0
# Propertycount        0
# dtype: int64

# %%
# Bathroom
br = df['Bathroom'].mean()
df['Bathroom'].fillna(br , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\1909687704.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Bathroom'].fillna(br , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             0
# Postcode             0
# Bedroom2             0
# Bathroom             0
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           0
# Propertycount        0
# dtype: int64

# %%
# Car
c = df['Car'].mean()
df['Car'].fillna(c , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\1191555092.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Car'].fillna(c , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             0
# Postcode             0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           0
# Propertycount        0
# dtype: int64

# %%
# Landsize
ls = df['Landsize'].mean()
df['Landsize'].fillna(ls , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\4187796824.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Landsize'].fillna(ls , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             0
# Postcode             0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize             0
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           0
# Propertycount        0
# dtype: int64

# %%
# BuildingArea
bd = df['BuildingArea'].mean()
df['BuildingArea'].fillna(bd , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\482468714.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BuildingArea'].fillna(bd , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             0
# Postcode             0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize             0
# BuildingArea         0
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           0
# Propertycount        0
# dtype: int64

# %%
# YearBuilt
yb = df['YearBuilt'].median()
df['YearBuilt'].fillna(yb , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\1037077532.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['YearBuilt'].fillna(yb , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
# CouncilArea
ca = df['CouncilArea'].mode()[0]
df['CouncilArea'].fillna(ca , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\2822287107.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CouncilArea'].fillna(ca , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
df.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# YearBuilt           0
# CouncilArea         0
# Lattitude        4304
# Longtitude       4304
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
# Lattitude
lt = df['Lattitude'].median()
df['Lattitude'].fillna(lt , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\3300436313.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Lattitude'].fillna(lt , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
# Longititude
ll = df['Longtitude'].mean()
df['Longtitude'].fillna(ll , inplace = True)
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_37616\1584398633.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Longtitude'].fillna(ll , inplace = True)
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# ...

# %%
df.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
# now we will start with encoding 
# doing on regionname
label = LabelEncoder()
df['Regionname'] = label.fit_transform(df['Regionname'])
df
# Out:
#              Suburb             Address  Rooms Type   Price Method  \
# 0        Abbotsford       68 Studley St      2    h 1056697     SS
# 1        Abbotsford        85 Turner St      2    h 1480000      S
# 2        Abbotsford     25 Bloomburg St      2    h 1035000      S
# 3        Abbotsford  18/659 Victoria St      3    u 1056697     VB
# 4        Abbotsford        5 Charles St      3    h 1465000     SP
# ...             ...                 ...    ...  ...     ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u 1056697     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h 1056697      S
# 23544     Yallambie        17 Amaroo Wy      4    h 1100000      S
# 23545    Yarraville          6 Agnes St      4    h 1285000     SP
# 23546    Yarraville       33 Freeman St      4    h 1050000     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03-09-2016         2      3067  ...         1    1
# ...

# %%
df['CouncilArea'].unique()
# Out:
# array(['Yarra', 'Boroondara', 'Moonee Valley', 'Port Phillip', 'Darebin',
#        'Hobsons Bay', 'Stonnington', 'Monash', 'Glen Eira', 'Whitehorse',
#        'Maribyrnong', 'Bayside', 'Moreland', 'Manningham', 'Banyule',
#        'Melbourne', 'Kingston', 'Brimbank', 'Hume', 'Knox', 'Maroondah',
#        'Casey', 'Melton', 'Greater Dandenong', 'Nillumbik', 'Whittlesea',
#        'Cardinia', 'Frankston', 'Macedon Ranges', 'Yarra Ranges',
#        'Wyndham', 'Moorabool', 'Unavailable', 'Mitchell'], dtype=object)

# %%
# performing label on type 
df['Type'] = label.fit_transform(df['Type'])
df
# Out:
#              Suburb             Address  Rooms  Type   Price Method  \
# 0        Abbotsford       68 Studley St      2     0 1056697     SS
# 1        Abbotsford        85 Turner St      2     0 1480000      S
# 2        Abbotsford     25 Bloomburg St      2     0 1035000      S
# 3        Abbotsford  18/659 Victoria St      3     2 1056697     VB
# 4        Abbotsford        5 Charles St      3     0 1465000     SP
# ...             ...                 ...    ...   ...     ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3     2 1056697     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4     0 1056697      S
# 23544     Yallambie        17 Amaroo Wy      4     0 1100000      S
# 23545    Yarraville          6 Agnes St      4     0 1285000     SP
# 23546    Yarraville       33 Freeman St      4     0 1050000     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03-09-2016         2      3067  ...         1    1
# ...

# %%
df['Method'].unique()
# Out:
# array(['SS', 'S', 'VB', 'SP', 'PI', 'SN', 'W', 'PN', 'SA'], dtype=object)

# %%
# performing label encoding on method column
df['Method'] = label.fit_transform(df['Method'])
df
# Out:
#              Suburb             Address  Rooms  Type   Price  Method  \
# 0        Abbotsford       68 Studley St      2     0 1056697       6
# 1        Abbotsford        85 Turner St      2     0 1480000       2
# 2        Abbotsford     25 Bloomburg St      2     0 1035000       2
# 3        Abbotsford  18/659 Victoria St      3     2 1056697       7
# 4        Abbotsford        5 Charles St      3     0 1465000       5
# ...             ...                 ...    ...   ...     ...     ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3     2 1056697       1
# 23543  Wyndham Vale    19 Dalrymple Bvd      4     0 1056697       2
# 23544     Yallambie        17 Amaroo Wy      4     0 1100000       2
# 23545    Yarraville          6 Agnes St      4     0 1285000       5
# 23546    Yarraville       33 Freeman St      4     0 1050000       7
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
# applying onehot
onehot = pd.get_dummies(df, columns = ['Suburb', 'SellerG', 'CouncilArea'], dtype = int)

# %%
onehot
# Out:
#                   Address  Rooms  Type   Price  Method        Date  Distance  \
# 0           68 Studley St      2     0 1056697       6  03-09-2016         2
# 1            85 Turner St      2     0 1480000       2  03-12-2016         2
# 2         25 Bloomburg St      2     0 1035000       2  04-02-2016         2
# 3      18/659 Victoria St      3     2 1056697       7  04-02-2016         2
# 4            5 Charles St      3     0 1465000       5  04-03-2017         2
# ...                   ...    ...   ...     ...     ...         ...       ...
# 23542     25 Clitheroe Dr      3     2 1056697       1  26-08-2017        27
# 23543    19 Dalrymple Bvd      4     0 1056697       2  26-08-2017        27
# 23544        17 Amaroo Wy      4     0 1100000       2  26-08-2017        13
# 23545          6 Agnes St      4     0 1285000       5  26-08-2017         6
# 23546       33 Freeman St      4     0 1050000       7  26-08-2017         6
#
# ...

# %%
df.drop('Address' , axis = 1 , inplace = True)

# %%
df
# Out:
#              Suburb  Rooms  Type   Price  Method        SellerG        Date  \
# 0        Abbotsford      2     0 1056697       6         Jellis  03-09-2016
# 1        Abbotsford      2     0 1480000       2         Biggin  03-12-2016
# 2        Abbotsford      2     0 1035000       2         Biggin  04-02-2016
# 3        Abbotsford      3     2 1056697       7         Rounds  04-02-2016
# 4        Abbotsford      3     0 1465000       5         Biggin  04-03-2017
# ...             ...    ...   ...     ...     ...            ...         ...
# 23542  Wyndham Vale      3     2 1056697       1      Harcourts  26-08-2017
# 23543  Wyndham Vale      4     0 1056697       2  hockingstuart  26-08-2017
# 23544     Yallambie      4     0 1100000       2     Buckingham  26-08-2017
# 23545    Yarraville      4     0 1285000       5        Village  26-08-2017
# 23546    Yarraville      4     0 1050000       7        Village  26-08-2017
#
# ...

# %%
df = onehot
df
# Out:
#                   Address  Rooms  Type   Price  Method        Date  Distance  \
# 0           68 Studley St      2     0 1056697       6  03-09-2016         2
# 1            85 Turner St      2     0 1480000       2  03-12-2016         2
# 2         25 Bloomburg St      2     0 1035000       2  04-02-2016         2
# 3      18/659 Victoria St      3     2 1056697       7  04-02-2016         2
# 4            5 Charles St      3     0 1465000       5  04-03-2017         2
# ...                   ...    ...   ...     ...     ...         ...       ...
# 23542     25 Clitheroe Dr      3     2 1056697       1  26-08-2017        27
# 23543    19 Dalrymple Bvd      4     0 1056697       2  26-08-2017        27
# 23544        17 Amaroo Wy      4     0 1100000       2  26-08-2017        13
# 23545          6 Agnes St      4     0 1285000       5  26-08-2017         6
# 23546       33 Freeman St      4     0 1050000       7  26-08-2017         6
#
# ...

# %%
# Address colmn dropped
df.drop('Address' , axis = 1 , inplace = True)
df
# Out:
#        Rooms  Type   Price  Method        Date  Distance  Postcode  Bedroom2  \
# 0          2     0 1056697       6  03-09-2016         2      3067         2
# 1          2     0 1480000       2  03-12-2016         2      3067         2
# 2          2     0 1035000       2  04-02-2016         2      3067         2
# 3          3     2 1056697       7  04-02-2016         2      3067         3
# 4          3     0 1465000       5  04-03-2017         2      3067         3
# ...      ...   ...     ...     ...         ...       ...       ...       ...
# 23542      3     2 1056697       1  26-08-2017        27      3024         3
# 23543      4     0 1056697       2  26-08-2017        27      3024         3
# 23544      4     0 1100000       2  26-08-2017        13      3085         4
# 23545      4     0 1285000       5  26-08-2017         6      3013         4
# 23546      4     0 1050000       7  26-08-2017         6      3013         4
#
# ...

# %%
# changing tha date type and extracting the year 
df['Date']=pd.to_datetime(df['Date'],dayfirst=True)
df['year']=df['Date'].dt.year

# %%
df
# Out:
#        Rooms  Type   Price  Method       Date  Distance  Postcode  Bedroom2  \
# 0          2     0 1056697       6 2016-09-03         2      3067         2
# 1          2     0 1480000       2 2016-12-03         2      3067         2
# 2          2     0 1035000       2 2016-02-04         2      3067         2
# 3          3     2 1056697       7 2016-02-04         2      3067         3
# 4          3     0 1465000       5 2017-03-04         2      3067         3
# ...      ...   ...     ...     ...        ...       ...       ...       ...
# 23542      3     2 1056697       1 2017-08-26        27      3024         3
# 23543      4     0 1056697       2 2017-08-26        27      3024         3
# 23544      4     0 1100000       2 2017-08-26        13      3085         4
# 23545      4     0 1285000       5 2017-08-26         6      3013         4
# 23546      4     0 1050000       7 2017-08-26         6      3013         4
#
# ...

# %%
# here i have dropped date after extracting year and colmn have been added
df.drop('Date' , axis = 1 , inplace = True)

# %%
df
# Out:
#        Rooms  Type   Price  Method  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2     0 1056697       6         2      3067         2         1
# 1          2     0 1480000       2         2      3067         2         1
# 2          2     0 1035000       2         2      3067         2         1
# 3          3     2 1056697       7         2      3067         3         2
# 4          3     0 1465000       5         2      3067         3         2
# ...      ...   ...     ...     ...       ...       ...       ...       ...
# 23542      3     2 1056697       1        27      3024         3         1
# 23543      4     0 1056697       2        27      3024         3         2
# 23544      4     0 1100000       2        13      3085         4         3
# 23545      4     0 1285000       5         6      3013         4         1
# 23546      4     0 1050000       7         6      3013         4         2
#
# ...

# %%
# Findiing the current year 
import datetime
current_year = datetime.datetime.now().year
print(current_year)
# Out:
# 2026

# %%
# Adding the colmn duration
df['Duration'] = current_year - df['year']
df
# Out:
#        Rooms  Type   Price  Method  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2     0 1056697       6         2      3067         2         1
# 1          2     0 1480000       2         2      3067         2         1
# 2          2     0 1035000       2         2      3067         2         1
# 3          3     2 1056697       7         2      3067         3         2
# 4          3     0 1465000       5         2      3067         3         2
# ...      ...   ...     ...     ...       ...       ...       ...       ...
# 23542      3     2 1056697       1        27      3024         3         1
# 23543      4     0 1056697       2        27      3024         3         2
# 23544      4     0 1100000       2        13      3085         4         3
# 23545      4     0 1285000       5         6      3013         4         1
# 23546      4     0 1050000       7         6      3013         4         2
#
# ...

# %%
# dropped the year column
df.drop('year' , axis = 1 , inplace = True)

# %%
df
# Out:
#        Rooms  Type   Price  Method  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2     0 1056697       6         2      3067         2         1
# 1          2     0 1480000       2         2      3067         2         1
# 2          2     0 1035000       2         2      3067         2         1
# 3          3     2 1056697       7         2      3067         3         2
# 4          3     0 1465000       5         2      3067         3         2
# ...      ...   ...     ...     ...       ...       ...       ...       ...
# 23542      3     2 1056697       1        27      3024         3         1
# 23543      4     0 1056697       2        27      3024         3         2
# 23544      4     0 1100000       2        13      3085         4         3
# 23545      4     0 1285000       5         6      3013         4         1
# 23546      4     0 1050000       7         6      3013         4         2
#
# ...

# %%
# now moving to normalizing
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
# std the price column
df['Price'] = scaler.fit_transform(df[['Price']])

# %%
df
# Out:
#        Rooms  Type  Price  Method  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2     0      0       6         2      3067         2         1
# 1          2     0      1       2         2      3067         2         1
# 2          2     0     -0       2         2      3067         2         1
# 3          3     2      0       7         2      3067         3         2
# 4          3     0      1       5         2      3067         3         2
# ...      ...   ...    ...     ...       ...       ...       ...       ...
# 23542      3     2      0       1        27      3024         3         1
# 23543      4     0      0       2        27      3024         3         2
# 23544      4     0      0       2        13      3085         4         3
# 23545      4     0      0       5         6      3013         4         1
# 23546      4     0     -0       7         6      3013         4         2
#
#        Car  Landsize  ...  CouncilArea_Nillumbik  CouncilArea_Port Phillip  \
# ...

# %%
# now on postcode colmn
df['Postcode'] = scaler.fit_transform(df[['Postcode']])

# %%
df
# Out:
#        Rooms  Type  Price  Method  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2     0      0       6         2        -0         2         1
# 1          2     0      1       2         2        -0         2         1
# 2          2     0     -0       2         2        -0         2         1
# 3          3     2      0       7         2        -0         3         2
# 4          3     0      1       5         2        -0         3         2
# ...      ...   ...    ...     ...       ...       ...       ...       ...
# 23542      3     2      0       1        27        -1         3         1
# 23543      4     0      0       2        27        -1         3         2
# 23544      4     0      0       2        13        -0         4         3
# 23545      4     0      0       5         6        -1         4         1
# 23546      4     0     -0       7         6        -1         4         2
#
#        Car  Landsize  ...  CouncilArea_Nillumbik  CouncilArea_Port Phillip  \
# ...

# %%
# now on landsize colmn
df['Landsize'] = scaler.fit_transform(df[['Landsize']])

# %%
df
# Out:
#        Rooms  Type  Price  Method  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2     0      0       6         2        -0         2         1
# 1          2     0      1       2         2        -0         2         1
# 2          2     0     -0       2         2        -0         2         1
# 3          3     2      0       7         2        -0         3         2
# 4          3     0      1       5         2        -0         3         2
# ...      ...   ...    ...     ...       ...       ...       ...       ...
# 23542      3     2      0       1        27        -1         3         1
# 23543      4     0      0       2        27        -1         3         2
# 23544      4     0      0       2        13        -0         4         3
# 23545      4     0      0       5         6        -1         4         1
# 23546      4     0     -0       7         6        -1         4         2
#
#        Car  Landsize  ...  CouncilArea_Nillumbik  CouncilArea_Port Phillip  \
# ...

# %%
# now on distance colmn
df['Distance'] = scaler.fit_transform(df[['Distance']])

# %%
df
# Out:
#        Rooms  Type  Price  Method  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2     0      0       6        -1        -0         2         1
# 1          2     0      1       2        -1        -0         2         1
# 2          2     0     -0       2        -1        -0         2         1
# 3          3     2      0       7        -1        -0         3         2
# 4          3     0      1       5        -1        -0         3         2
# ...      ...   ...    ...     ...       ...       ...       ...       ...
# 23542      3     2      0       1         3        -1         3         1
# 23543      4     0      0       2         3        -1         3         2
# 23544      4     0      0       2         0        -0         4         3
# 23545      4     0      0       5        -1        -1         4         1
# 23546      4     0     -0       7        -1        -1         4         2
#
#        Car  Landsize  ...  CouncilArea_Nillumbik  CouncilArea_Port Phillip  \
# ...

# %%
# now on duration colmn
df['Duration'] = scaler.fit_transform(df[['Duration']])

# %%
df
# Out:
#        Rooms  Type  Price  Method  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2     0      0       6        -1        -0         2         1
# 1          2     0      1       2        -1        -0         2         1
# 2          2     0     -0       2        -1        -0         2         1
# 3          3     2      0       7        -1        -0         3         2
# 4          3     0      1       5        -1        -0         3         2
# ...      ...   ...    ...     ...       ...       ...       ...       ...
# 23542      3     2      0       1         3        -1         3         1
# 23543      4     0      0       2         3        -1         3         2
# 23544      4     0      0       2         0        -0         4         3
# 23545      4     0      0       5        -1        -1         4         1
# 23546      4     0     -0       7        -1        -1         4         2
#
#        Car  Landsize  ...  CouncilArea_Nillumbik  CouncilArea_Port Phillip  \
# ...

# %%
# now on postcode colmn
df.drop(columns=['Propertycount' , 'Distance' , 'Lattitude', 'YearBuilt'] , axis = 1 , inplace = True)

# %%
df
# Out:
#        Rooms  Type  Price  Method  Postcode  Bedroom2  Bathroom  Car  \
# 0          2     0      0       6        -0         2         1    1
# 1          2     0      1       2        -0         2         1    1
# 2          2     0     -0       2        -0         2         1    0
# 3          3     2      0       7        -0         3         2    1
# 4          3     0      1       5        -0         3         2    0
# ...      ...   ...    ...     ...       ...       ...       ...  ...
# 23542      3     2      0       1        -1         3         1    0
# 23543      4     0      0       2        -1         3         2    2
# 23544      4     0      0       2        -0         4         3    2
# 23545      4     0      0       5        -1         4         1    1
# 23546      4     0     -0       7        -1         4         2    2
#
#        Landsize  BuildingArea  ...  CouncilArea_Nillumbik  \
# 0            -0           155  ...                      0
# ...

# %%
df.isna().sum()
# Out:
# Rooms                       0
# Type                        0
# Price                       0
# Method                      0
# Postcode                    0
#                            ..
# CouncilArea_Whittlesea      0
# CouncilArea_Wyndham         0
# CouncilArea_Yarra           0
# CouncilArea_Yarra Ranges    0
# Duration                    0
# Length: 713, dtype: int64
