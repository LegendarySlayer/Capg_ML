# %% [markdown]
# Feature Scaling\
# Normalization

# %%
data = {
    "Sname": ["S1", "S2","S3","S4"],
    "Height": [162 , 171 , 155 , 165],
    "Weight": [62 , 60 , 50 , 62],
    "Speed": [5 , 3 , 7 , 2]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Sname  Height  Weight  Speed
# 0    S1     162      62      5
# 1    S2     171      60      3
# 2    S3     155      50      7
# 3    S4     165      62      2

# %%
import pandas as pd
from sklearn.preprocessing import Normalizer
norm = Normalizer()
cols = df[["Height" , "Weight" , "Speed"]]
norm_data = norm.fit_transform(cols)
df = pd.DataFrame(norm_data , columns = cols.columns)
df
# Out:
#      Height    Weight     Speed
# 0  0.933551  0.357285  0.028813
# 1  0.943471  0.331042  0.016552
# 2  0.950831  0.306720  0.042941
# 3  0.936036  0.351722  0.011346

# %% [markdown]
# Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
cols = df[["Height" , "Weight" , "Speed"]]
SS_data = SS.fit_transform(cols)
df = pd.DataFrame(SS_data , columns = cols.columns)
df
# Out:
#      Height    Weight     Speed
# 0 -1.097525  1.036045  0.320012
# 1  0.369543 -0.284259 -0.685998
# 2  1.458043 -1.507974  1.479146
# 3 -0.730061  0.756189 -1.113161
